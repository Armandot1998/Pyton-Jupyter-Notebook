# %% [markdown]
# # Trabajo: Introducción a la programación con Python

# %% [markdown]
# ### 1. Crear una funcion en Python que calcule el minimo común múltiplo de dos números.

# %%
# Definimos la función "calcular_mcm" con 2 parámetros de entrada

def calcular_mcm(a, b):       
# Utilizamos la función que nos permite obtener el número mayor de entre 2 en este caso
        A = max(a, b)
# Utilizamos la función que nos permite obtener el número mínimo de entre 2 en este caso 
        B = min(a, b)
    
# Realizamos el ciclo encargado de realizar las iteraciones   
        while B:       
            mcd = B  
            B = A % B  
            A = mcd
            mcm =  (a * b) // mcd
# Esta funcion nos devolverá el mínimo común múltiplo de los valores ingresados como parametros en la función "calcular_mcm"
        return mcm 

# Utilizamos la funcion "calcular_mcm" mediante un "print()" adicional enviamos los 2 números enteros como parametros

print("El mínimo común múltiplo es: " + str(calcular_mcm(2, 4)))
# Out:
# El mínimo común múltiplo es: 4

# %% [markdown]
# ### 2. Crear una función en Python que calcule el máximo común divisor de dos números.

# %%
# Máximo común divisor: el número más grande que divide dos números

# Definimos una función "calcular_mcd" con 2 parámetros de entrada que deben ser enteros positivos
def calcular_mcd(a, b):
    
# Utilizamos la función que nos permite obtener el número mayor de entre 2 en este caso   
    A = max(a, b)
# Utilizamos la función que nos permite obtener el número mínimo de entre 2 en este caso 
    B = min(a, b)
    
# Realizamos el ciclo encargado de realizar las iteraciones    
    while B != 0:
        res = B
        B = A % B
        A = res
        
# Esta funcion nos devolverá el mínimo común múltiplo de los valores ingresados como parametros en la función "calcular_mcd"        
    return res

# Utilizamos la funcion "calcular_mcd" mediante un "print()" adicional enviamos los 2 números enteros como parametros
print("El máximo común divisor es: " + str(calcular_mcd(12, 34)))
# Out:
# El máximo común divisor es: 2

# %% [markdown]
# ### 3. Basándote en datos aleatorios (los que quieras) crea un gráfico de tarta (pie chart) con Matplotlib.

# %%
import matplotlib.pyplot as plt

# A continuacion se muestra un gráfico que demuestra la preferencia de las personas en cuando a temas de libros


# Gráfico circular, donde se ordenarán y trazarán los cortes en sentido antihorario:
labels = 'Deportes', 'Cultura', 'Sociedad', 'Tecnología'
sizes = [15, 30, 15, 40]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  
# La relación de aspecto igual garantiza que el pastel se dibuje como un círculo.

plt.show()

# %% [markdown]
# ### 4. Basándote en datos aleatorios, crea un Scattler Plot con Matplotlib. Explica para que se pueden ser útiles estos gráficos.

# %%
import numpy as np
import matplotlib.pyplot as plt

# primero se definen las proporciones
r1 = 0.2       # 20%
r2 = r1 + 0.4  # 40%

# define algunos tamaños del marcador de dispersión
sizes = np.array([60, 80, 120])

# calcular los puntos del primer marcador circular
# estos son solo los puntos de origen (0, 0) + algunos (cos, sin) en un círculo
x1 = np.cos(2 * np.pi * np.linspace(0, r1))
y1 = np.sin(2 * np.pi * np.linspace(0, r1))
xy1 = np.row_stack([[0, 0], np.column_stack([x1, y1])])
s1 = np.abs(xy1).max()

x2 = np.cos(2 * np.pi * np.linspace(r1, r2))
y2 = np.sin(2 * np.pi * np.linspace(r1, r2))
xy2 = np.row_stack([[0, 0], np.column_stack([x2, y2])])
s2 = np.abs(xy2).max()

x3 = np.cos(2 * np.pi * np.linspace(r2, 1))
y3 = np.sin(2 * np.pi * np.linspace(r2, 1))
xy3 = np.row_stack([[0, 0], np.column_stack([x3, y3])])
s3 = np.abs(xy3).max()

fig, ax = plt.subplots()
ax.scatter(range(3), range(3), marker=xy1, s=s2**2 * sizes, facecolor='blue')
ax.scatter(range(3), range(3), marker=xy2, s=s2**2 * sizes, facecolor='blue')
ax.scatter(range(3), range(3), marker=xy3, s=s2**2 * sizes, facecolor='blue')

plt.show()

# EXPLCACIÓN
# Entre sus usos está descubrir y mostrar las relaciones entre dos conjuntos asociados de datos 
# y confirmar relaciones anticipadas entre dos conjuntos asociados de datos.

# El diagrama de dispersión puede estudiar la relación entre:

# Dos factores o causas relacionadas con la calidad.
# Dos problemas de calidad.
# Un problema de calidad y su posible causa.

# %% [markdown]
# ### 5. Explicar cómo combinar 4 gráficos en una única figura (subplot).

# %%
# A continuación se muestra como mostrar n graficas juntas en una sola gráfica
# Ejemplos que ilustran el uso de plt.subplots ().
# Esta función crea una figura y una cuadrícula de subtramas con una sola llamada, mientras
# proporcionando un control razonable sobre cómo se crean las parcelas individuales. por
# ajuste muy refinado de la creación de subtramas, aún puede usar add_subplot()
# directamente en una nueva figura.

import matplotlib.pyplot as plt
import numpy as np

# Datos simples para mostrar en varias formas
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

plt.close('Todo')

# Solo una figura y una subtrama
f, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('Gráfica simple')

# Dos subtramas, descomprima la matriz de ejes inmediatamente
f, axarr = plt.subplots(2, sharex=True)
axarr[0].plot(x, y)
axarr[0].set_title('Compartir eje X')
axarr[1].scatter(x, y)

# Dos subtramas, la matriz de ejes es 1-d
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax1.set_title('Compartir eje Y')
ax2.scatter(x, y)

# Tres subtramas que comparten ambos ejes x / y
f, (ax1, ax2, ax3) = plt.subplots(3, sharex=True, sharey=True)
ax1.plot(x, y)
ax1.set_title('Compartiendo ambos ejes')
ax2.scatter(x, y)
ax3.scatter(x, 2 * y ** 2 - 1, color='r')
# Figura de ajuste fino; hacer subtramas cercanas entre sí y ocultar x ticks para
# todo menos la trama inferior.
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

# compartir filas y columnas
f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex='col', sharey='row')
ax1.plot(x, y)
ax1.set_title('Compartir x por columna, y por fila')
ax2.scatter(x, y)
ax3.scatter(x, 2 * y ** 2 - 1, color='r')
ax4.plot(x, 2 * y ** 2 - 1, color='r')

plt.show()

# En conclusión podemos unir dos o mas gráficas espesificando cuantas y cuales vendrían a ser, como se mostró anteriormente
